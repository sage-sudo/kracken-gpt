# %% [markdown]
# > Best Bid\Ask, Spead and Imblance

# %% [markdown]
# ___

# %% [markdown]
# # Imports

# %%
import asyncio
import websockets
import threading
import json
import time
import requests
from collections import OrderedDict

import ssl
import certifi

# For dev/debug — disables SSL verification. DO NOT use in prod.
ssl_context = ssl._create_unverified_context()
# Use this for proper SSL:
# ssl_context = ssl.create_default_context(cafile=certifi.where())

# %% [markdown]
# ___

# %% [markdown]
# # Local Order Book

# %%
class LocalOrderBook:
    def __init__(self):
        self.bids = OrderedDict()
        self.asks = OrderedDict()

    def update(self, updates, side):
        book = self.bids if side == "b" else self.asks
        for update in updates:
            price, volume = float(update[0]), float(update[1])
            if volume == 0:
                book.pop(price, None)
            else:
                book[price] = volume

        if side == "b":
            self.bids = OrderedDict(sorted(book.items(), reverse=True))
        else:
            self.asks = OrderedDict(sorted(book.items()))

    def patch_from_snapshot(self, snapshot_bids, snapshot_asks):
        self._patch_side(snapshot_bids, self.bids, side="b")
        self._patch_side(snapshot_asks, self.asks, side="a")

    def _patch_side(self, snapshot, book, side):
        if len(book) >= 100:
            return

        for update in snapshot:
            price, volume = float(update[0]), float(update[1])
            if price not in book and len(book) < 100:
                book[price] = volume

        if side == "b":
            self.bids = OrderedDict(sorted(book.items(), reverse=True))
        else:
            self.asks = OrderedDict(sorted(book.items()))

    def top_of_book(self):
        best_bid = next(iter(self.bids.items()), (None, None))
        best_ask = next(iter(self.asks.items()), (None, None))
        return best_bid, best_ask

    def spread(self):
        bid, ask = self.top_of_book()
        if bid[0] is not None and ask[0] is not None:
            return round(ask[0] - bid[0], 2)
        return None

    def order_book_imbalance(self, depth=10):
        top_bids = list(self.bids.items())[:depth]
        top_asks = list(self.asks.items())[:depth]

        bid_vol = sum(vol for _, vol in top_bids)
        ask_vol = sum(vol for _, vol in top_asks)

        if bid_vol + ask_vol == 0:
            return None

        imbalance = (bid_vol - ask_vol) / (bid_vol + ask_vol)
        return round(imbalance, 4)

    def needs_patch(self):
        return len(self.bids) < 100 or len(self.asks) < 100

# %% [markdown]
# ___

# %% [markdown]
# # Kraken Client

# %%
class KrakenL2Client:
    def __init__(self, pairs=["XBT/USD"], depth=100):
        self.pairs = pairs
        self.depth = depth
        self.uri = "wss://ws.kraken.com"
        self.loop = None
        self.thread = None
        self.stop_event = threading.Event()
        self.order_books = {pair: LocalOrderBook() for pair in self.pairs}
        self.last_patch_time = time.time()

    async def connect(self):
        while not self.stop_event.is_set():
            try:
                async with websockets.connect(self.uri, ssl=ssl_context) as websocket:
                    await websocket.send(json.dumps({
                        "event": "subscribe",
                        "pair": self.pairs,
                        "subscription": {"name": "book", "depth": self.depth}
                    }))
                    print(f"📡 Subscribed to: {', '.join(self.pairs)}")

                    while not self.stop_event.is_set():
                        try:
                            message = await websocket.recv()
                            self.handle_message(json.loads(message))
                            self.maybe_patch_books()
                        except Exception as e:
                            print(f"⚠️ Message handling error: {e}")
                            break
            except Exception as e:
                print(f"💥 WebSocket connection failed, retrying in 5s: {e}")
                await asyncio.sleep(5)

    def maybe_patch_books(self):
        if time.time() - self.last_patch_time < 5:
            return

        for pair in self.pairs:
            book = self.order_books[pair]
            if book.needs_patch():
                print(f"🔧 Patching {pair}...")
                bids, asks = self.fetch_snapshot(pair)
                if bids and asks:
                    book.patch_from_snapshot(bids, asks)
        self.last_patch_time = time.time()

    def fetch_snapshot(self, pair):
        symbol = pair.replace("/", "")
        url = f"https://api.kraken.com/0/public/Depth?pair={symbol}&count=100"
        try:
            resp = requests.get(url, timeout=5)
            data = resp.json()
            key = list(data["result"].keys())[0]
            return data["result"][key]["bids"], data["result"][key]["asks"]
        except Exception as e:
            print(f"❌ Snapshot error: {e}")
            return None, None

    def handle_message(self, message):
        if isinstance(message, dict):
            if message.get("event") in ["heartbeat", "systemStatus", "subscriptionStatus"]:
                return

        if isinstance(message, list) and len(message) > 1:
            data = message[1]
            pair = message[-1]
            book = self.order_books.get(pair)
            if not book:
                return

            if 'a' in data:
                book.update(data['a'], 'a')
            if 'b' in data:
                book.update(data['b'], 'b')

            bid, ask = book.top_of_book()
            spread = book.spread()
            imbalance = book.order_book_imbalance()

            print(f"📊 {pair} → Bid: {bid[0]} | Ask: {ask[0]} | Spread: {spread} | Imbalance: {imbalance}")

    def start(self):
        self.loop = asyncio.new_event_loop()
        asyncio.set_event_loop(self.loop)
        self.loop.run_until_complete(self.connect())

    def run_in_thread(self):
        self.thread = threading.Thread(target=self.start)
        self.thread.start()

    def stop(self):
        self.stop_event.set()
        if self.loop:
            self.loop.call_soon_threadsafe(self.loop.stop)
        if self.thread:
            self.thread.join()

# %% [markdown]
# ___

# %% [markdown]
# # Run

# %%
# ---------------------- USAGE ---------------------- #
if __name__ == "__main__":
    client = KrakenL2Client(pairs=["XBT/USD", "ETH/USD"])
    client.run_in_thread()

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        print("🛑 Stopping client...")
        client.stop()
# Out:
# 📡 Subscribed to: XBT/USD, ETH/USD
# 📊 XBT/USD → Bid: None | Ask: None | Spread: None | Imbalance: None
# 📊 ETH/USD → Bid: None | Ask: None | Spread: None | Imbalance: None
# 📊 XBT/USD → Bid: None | Ask: 103743.2 | Spread: None | Imbalance: -1.0
# 📊 XBT/USD → Bid: None | Ask: 103740.8 | Spread: None | Imbalance: -1.0
# 📊 ETH/USD → Bid: 2398.17 | Ask: None | Spread: None | Imbalance: 1.0
# 📊 ETH/USD → Bid: 2398.17 | Ask: 2408.04 | Spread: 9.87 | Imbalance: -0.8124
# 📊 XBT/USD → Bid: None | Ask: 103740.8 | Spread: None | Imbalance: -1.0
# 📊 XBT/USD → Bid: None | Ask: 103700.8 | Spread: None | Imbalance: -1.0
# 📊 ETH/USD → Bid: 2406.56 | Ask: 2408.04 | Spread: 1.48 | Imbalance: -0.809
# 📊 XBT/USD → Bid: None | Ask: 103700.8 | Spread: None | Imbalance: -1.0
# 📊 ETH/USD → Bid: 2406.57 | Ask: 2408.04 | Spread: 1.47 | Imbalance: -0.8071
# 📊 ETH/USD → Bid: 2406.57 | Ask: 2408.04 | Spread: 1.47 | Imbalance: -0.5991
# 📊 XBT/USD → Bid: None | Ask: 103700.8 | Spread: None | Imbalance: -1.0
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103700.8 | Spread: 20.9 | Imbalance: 0.038
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.038
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.1915
# 📊 ETH/USD → Bid: 2406.57 | Ask: 2408.04 | Spread: 1.47 | Imbalance: -0.7218
# 📊 ETH/USD → Bid: 2406.56 | Ask: 2408.04 | Spread: 1.48 | Imbalance: -0.7228
# 📊 ETH/USD → Bid: 2406.56 | Ask: 2408.04 | Spread: 1.48 | Imbalance: -0.6314
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.04 | Spread: 0.47 | Imbalance: -0.0259
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.04 | Spread: 0.47 | Imbalance: -0.006
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.04 | Spread: 0.47 | Imbalance: -0.0544
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.04 | Spread: 0.47 | Imbalance: -0.0511
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.04 | Spread: 0.47 | Imbalance: 0.1964
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.1916
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.207
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.211
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.2109
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2119
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.207
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2119
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.2109
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.1978
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.207
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2067
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2067
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2035
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.248
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.263
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.261
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2653
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2383
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2383
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2338
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.1788
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2383
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2311
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2243
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2195
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2264
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2338
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2338
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.1788
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.1668
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.1668
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.011
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.1854
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.1854
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.1668
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.1668
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0021
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.1854
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.007
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.007
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.007
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0021
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0021
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2179
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2209
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.2182
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0023
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: -0.1507
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: -0.1507
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0016
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0016
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0002
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0016
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.1854
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0016
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0016
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.1978
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: 0.0988
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.1516
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.1528
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: -0.0116
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.3556
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.5262
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.5262
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.5262
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.5262
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.6359
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103688.8 | Spread: 8.9 | Imbalance: -0.0116
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.6359
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0116
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.6359
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.5262
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.066
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.523
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.523
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.6333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.6333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.3456
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.1701
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.1701
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.1786
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.1761
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.282
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.1793
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.282
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0116
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.066
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.1077
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: -0.0277
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0826
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0826
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0791
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0041
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0127
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2408.0 | Spread: 0.43 | Imbalance: 0.0776
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0788
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0803
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0127
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.1477
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2503
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.2152
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0803
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0579
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0579
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1561
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1724
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1724
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2503
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1685
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1724
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1725
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1561
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1549
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3202
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3202
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3202
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3204
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1563
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3204
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5346
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.4421
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.4421
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5237
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5237
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5237
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2503
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3067
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3153
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1509
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2503
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1356
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1411
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2378
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1414
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.2995
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1384
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1325
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1392
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1387
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1387
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1408
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3018
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1396
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1401
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1401
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1458
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1458
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1458
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1607
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1568
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1568
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1618
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1621
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1618
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1657
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1602
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1606
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1606
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1594
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1554
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2378
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1594
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1594
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1594
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1593
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1439
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3059
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1439
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1439
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1439
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1399
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1399
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1439
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3022
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3026
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3026
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3165
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3022
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.1527
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.0032
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3022
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3022
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3022
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3022
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5218
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3022
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1413
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3022
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3022
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1376
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1337
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1342
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1342
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1375
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1342
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.2976
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.2976
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5152
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5195
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.0032
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5195
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3029
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1436
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1379
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1379
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1379
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1379
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.2975
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1378
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1378
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0062
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1378
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1382
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1382
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.1404
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0062
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.2979
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1382
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1382
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1382
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1382
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0062
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1382
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.1287
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1377
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.2974
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1377
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1377
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1663
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0054
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1602
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3182
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3182
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3182
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3182
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3185
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3238
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3234
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1659
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3234
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1659
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1659
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0054
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1663
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1663
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3238
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1663
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1663
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1666
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3241
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1666
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1663
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3238
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1663
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3239
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3239
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.0039
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3239
# 🔧 Patching XBT/USD...
# ❌ Snapshot error: HTTPSConnectionPool(host='api.kraken.com', port=443): Max retries exceeded with url: /0/public/Depth?pair=XBTUSD&count=100 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))
# 🔧 Patching ETH/USD...
# ❌ Snapshot error: HTTPSConnectionPool(host='api.kraken.com', port=443): Max retries exceeded with url: /0/public/Depth?pair=ETHUSD&count=100 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3241
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1666
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3241
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1666
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1663
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2016
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.1971
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2016
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.0039
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0103
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0032
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2016
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2106
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.1197
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2106
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3239
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1663
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.2106
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: -0.0045
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.0166
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.011
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.0039
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.0039
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.011
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.011
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.011
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103699.9 | Spread: 20.0 | Imbalance: 0.011
# 📊 XBT/USD → Bid: 103679.9 | Ask: 103686.8 | Spread: 6.9 | Imbalance: 0.0111
# 📊 XBT/USD → Bid: 103680.0 | Ask: 103686.8 | Spread: 6.8 | Imbalance: 0.0135
# 📊 XBT/USD → Bid: 103680.0 | Ask: 103686.8 | Spread: 6.8 | Imbalance: 0.015
# 📊 XBT/USD → Bid: 103685.0 | Ask: 103686.8 | Spread: 1.8 | Imbalance: 0.0258
# 📊 XBT/USD → Bid: 103685.0 | Ask: 103686.8 | Spread: 1.8 | Imbalance: 0.0248
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.0298
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.0534
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.0582
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.1325
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.2932
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.2959
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3002
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3029
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.2974
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.2974
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3277
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3248
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3248
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3248
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3248
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3223
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3223
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.1741
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.1668
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.1657
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.1579
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3073
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3126
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3091
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3141
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3129
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3155
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3155
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4213
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3726
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4211
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4986
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.509
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5108
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5095
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5101
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5095
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5082
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5095
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5093
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4859
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4862
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5063
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4853
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4833
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4833
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4833
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4853
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4872
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0393
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4718
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4925
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4886
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4879
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4875
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1629
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.6021
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5154
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4945
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4941
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4955
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4955
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4955
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.0397
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4955
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.166
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.166
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4955
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4955
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.166
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.166
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1703
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1703
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1703
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4955
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4955
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4955
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4955
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4912
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4605
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.142
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4676
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4685
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4621
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1751
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4429
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4429
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1771
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1809
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1776
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1776
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1815
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3447
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3451
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3451
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3451
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3451
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3428
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5567
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5567
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8415
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8465
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8415
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8434
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5531
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5529
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5531
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5531
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5531
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5552
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5552
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8448
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8448
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4429
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5577
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4484
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8448
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8448
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.4758
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4484
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5323
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3314
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3314
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3955
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3955
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3955
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6169
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5541
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5538
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8434
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8434
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8552
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7566
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4484
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.758
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.758
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7583
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7538
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7538
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5063
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5063
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5063
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5037
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5014
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4429
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4429
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4429
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5014
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5014
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5014
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5115
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5115
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5014
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5014
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5014
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5115
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5115
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5014
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5115
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.443
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4422
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4422
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5014
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7489
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7503
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5044
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3228
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3228
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3228
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.502
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3199
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3182
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4541
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4622
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4598
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.2899
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4598
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4669
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4612
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3198
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5019
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3198
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1759
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1759
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4612
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4612
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1759
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1735
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4612
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1759
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3198
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4612
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1738
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3198
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5019
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5019
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.4965
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5013
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5011
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5025
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5025
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5025
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4665
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4612
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3194
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3194
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3194
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3719
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3719
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3687
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3651
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.4944
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.4924
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7417
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7415
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7415
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7415
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7442
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7442
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7367
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5738
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7367
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7348
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7361
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8361
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9205
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9248
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8401
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7397
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5738
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7397
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.7415
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.5738
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.698
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5675
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5658
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5675
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5675
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5675
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5675
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5675
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5675
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5736
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5675
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5673
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6139
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6139
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6239
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.697
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.7018
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.7004
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6223
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4645
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.3674
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6223
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6243
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6243
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6231
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6231
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6231
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.6231
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8357
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.8357
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.835
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.835
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.835
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9094
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9083
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9083
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9083
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9083
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9083
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9083
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9005
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9083
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4645
# 📊 XBT/USD → Bid: 103686.7 | Ask: 103686.8 | Spread: 0.1 | Imbalance: 0.4645
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.9083
# ...
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3063
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1475
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3885
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3063
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.148
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.148
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.148
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3063
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1461
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1461
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1461
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3885
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3063
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3256
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5604
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3256
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3256
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3207
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.565
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5571
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.565
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5571
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5561
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5533
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.542
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.542
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5386
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3064
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3367
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3367
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3422
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3455
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3455
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3455
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3063
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3063
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1692
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3028
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1692
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1692
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3028
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1651
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3063
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3313
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3313
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1585
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3259
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1585
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3028
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3259
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3259
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3025
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3259
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3259
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3313
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2991
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3313
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3313
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3259
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3313
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1627
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1585
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1585
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1585
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1627
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3313
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1585
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3313
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.5647
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3368
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3368
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.31
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3065
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3324
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3324
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.327
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1538
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1579
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3027
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1606
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1606
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1606
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1606
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1606
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1579
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1579
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3325
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1645
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3325
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1645
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3027
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1645
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1689
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3365
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1689
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1648
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1648
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1648
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.331
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.331
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.331
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3389
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3389
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2991
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3389
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3389
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3444
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3444
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3389
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3444
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3444
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3281
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3773
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3281
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2926
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2926
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2929
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3281
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3274
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3219
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3219
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2965
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3274
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2964
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3281
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3281
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3281
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3281
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3281
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2928
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3281
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2899
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2933
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2933
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3422
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3422
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3422
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1564
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3457
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1564
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1564
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1522
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1522
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1564
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3337
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.333
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.325
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1564
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1564
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1564
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3457
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2972
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2963
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2972
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2937
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2937
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2937
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.293
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3338
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1569
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.3338
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1569
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1564
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.3752
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2972
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1569
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2972
# 📊 XBT/USD → Bid: 103688.8 | Ask: 103688.9 | Spread: 0.1 | Imbalance: 0.2972
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1569
# Exception in thread Thread-5 (start):
# Traceback (most recent call last):
#   File "C:\Users\trrallele\AppData\Local\anaconda3\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "c:\Users\trrallele\Momentum Metropolitan\REALEARN\CRYPTO STRATEGIES IN PYTHON\myenv2.0\Lib\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "C:\Users\trrallele\AppData\Local\anaconda3\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\trrallele\AppData\Local\Temp\ipykernel_34672\1525992026.py", line 86, in start
#   File "C:\Users\trrallele\AppData\Local\anaconda3\Lib\asyncio\base_events.py", line 651, in run_until_complete
#     raise RuntimeError('Event loop stopped before Future completed.')
# RuntimeError: Event loop stopped before Future completed.
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1569
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1569
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1569
# 📊 ETH/USD → Bid: 2407.57 | Ask: 2407.58 | Spread: 0.01 | Imbalance: 0.1569
# 🛑 Stopping client...
